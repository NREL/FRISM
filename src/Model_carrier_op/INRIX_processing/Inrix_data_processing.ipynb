# %%
import psycopg2
import gzip

# %%
from ast import literal_eval

# %%
import config

# %%
conn = psycopg2.connect(host="localhost",database="postgres", user="postgres", password="1234")

# %%
# create table: "trips" 
try:
    cursor = conn.cursor()
    
    create_table_query = '''CREATE TABLE trips
    (trip_id VARCHAR (50) NOT NULL,
device_id VARCHAR (50) NOT NULL,
provider_id VARCHAR (50) NOT NULL,
mode integer NOT NULL,
start_date timestamp,
start_dow integer,
end_date timestamp,
end_dow integer,
start_lat real,
start_lon real,
end_lat real,
end_lon real,
start_home BOOLEAN,
end_home BOOLEAN,
geospatial_type TEXT,
provider_type integer,
driving_profile integer,
vehicle_weight_class integer,
probe_source_type integer,
origin_zone TEXT,
dest_zone TEXT,
multiple_zones BOOLEAN,
multiple_corridors TEXT,
endpoint_type integer,
trip_mean_speed_kph double precision,
trip_max_speed_kph double precision,
trip_distance_m double precision,
movement_type integer,
origin_cbg TEXT,
dest_cbg TEXT,
start_tz TEXT,
end_tz TEXT); '''
    
    cursor.execute(create_table_query)
    conn.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while creating PostgreSQL table", error)
finally:
    #closing database connection.
        if(conn):
            cursor.close()
            conn.close()
            print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
# insert cvs into that
URL= '/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/trips/trips.csv'
try:
    cursor = conn.cursor()
    
    import_data = '''COPY trips FROM '/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/trips/trips.csv' DELIMITER ',' CSV; '''
    
    cursor.execute(import_data)
    conn.commit()
    print("Import successfully in PostgreSQL ")

except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while creating PostgreSQL table", error)
finally:
    #closing database connection.
        if(conn):
            cursor.close()
            conn.close()
            print("PostgreSQL connection is closed")
# Out:
# Error while creating PostgreSQL table could not open file "/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/trips/trips.csv" for reading: Permission denied
# HINT:  COPY FROM instructs the PostgreSQL server process to read a file. You may want a client-side facility such as psql's \copy.
#
# PostgreSQL connection is closed

# %%
# create table: "trips" 
try:
    cursor = conn.cursor()
    
    create_table_query = '''CREATE TABLE temp2
    (trip_id VARCHAR (50) NOT NULL,
device_id VARCHAR (50) NOT NULL,
provider_id VARCHAR (50) NOT NULL,
mode integer NOT NULL,
start_date timestamp,
start_dow integer,
end_date timestamp,
end_dow integer,
start_lat real,
start_lon real,
end_lat real,
end_lon real,
start_home BOOLEAN,
end_home BOOLEAN,
geospatial_type TEXT,
provider_type integer,
driving_profile integer,
vehicle_weight_class integer,
probe_source_type integer,
origin_zone TEXT,
dest_zone TEXT,
multiple_zones BOOLEAN,
multiple_corridors TEXT,
endpoint_type integer,
trip_mean_speed_kph double precision,
trip_max_speed_kph double precision,
trip_distance_m double precision,
movement_type integer,
origin_cbg TEXT,
dest_cbg TEXT,
start_tz TEXT,
end_tz TEXT); '''
    
    cursor.execute(create_table_query)
    conn.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while creating PostgreSQL table", error)
finally:
    #closing database connection.
        if(conn):
            cursor.close()
            conn.close()
            print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
conn = psycopg2.connect(host="localhost",database="postgres", user="postgres", password="1234")

# create table: "waypoints" 
try:
    cursor = conn.cursor()
    
    create_table_query = '''CREATE TABLE waypoints
    (trip_id VARCHAR (50) NOT NULL,
    waypoint_seq integer,
    capture_time timestamp,
    lat real,
    lon real,
    segment_id integer,
    zone_name VARCHAR (50),
    frc integer,
    device_id VARCHAR (50) NOT NULL,
    raw_speed real,
    raw_speed_metric TEXT); '''
    
    cursor.execute(create_table_query)
    conn.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while creating PostgreSQL table", error)
finally:
    #closing database connection.
        if(conn):
            cursor.close()
            conn.close()
            print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
f_list = ['/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints1.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints2.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints3.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints4.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints5.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints6.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints7.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints1.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints2.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints3.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints4.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints5.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints6.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints7.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170425_to_20170522/waypoints/waypoints8.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints1.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints2.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints3.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints4.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints5.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints6.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints7.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20170829_to_20170925/waypoints/waypoints8.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints1.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints2.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints3.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints4.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints5.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints6.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints7.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20171121_to_20171219/waypoints/waypoints8.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints1.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints2.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints3.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints4.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints5.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints6.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints7.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints8.csv',
'/Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints9.csv']

# %%
for file_name in f_list: 
    conn = psycopg2.connect(host="localhost",database="postgres", user="postgres", password="1234")
    try:
        cursor = conn.cursor()
        with open(file_name,'r') as f:
            cursor.copy_from(f,'waypoints', sep=",", null='""')
            conn.commit()
            print("Import successfully in PostgreSQL: %s" % file_name)

    except (Exception, psycopg2.DatabaseError) as error :
        print ("Error while creating PostgreSQL table", error)
    finally:
        #closing database connection.
            if(conn):
                cursor.close()
                conn.close()
                print("PostgreSQL connection is closed")
# Out:
# Import successfully in PostgreSQL: /Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints.csv
# PostgreSQL connection is closed
# Import successfully in PostgreSQL: /Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints1.csv
# PostgreSQL connection is closed
# Import successfully in PostgreSQL: /Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints2.csv
# PostgreSQL connection is closed
# Import successfully in PostgreSQL: /Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints3.csv
# PostgreSQL connection is closed
# Import successfully in PostgreSQL: /Users/kjeong/1_Work/1_SmartMobility/Data/INRIX/trips_usa_il_in_20180828_to_20180924/waypoints/waypoints4.csv
# PostgreSQL connection is closed
# ...
